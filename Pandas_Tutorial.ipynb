# %% [markdown]
# **Importing Library and Intro to sum basic functions**

# %%
import pandas as pd
import numpy as np

# %%
dic1 = {
    "name":['vikas', 'sanchi', 'tushi', 'adi'],
    "marks":[23,64,24,22],
    "city":['amritsar','varanasi','ranchi','tirupati']
}

# %%
df = pd.DataFrame(dic1)

# %%
df
# Out:
#      name  marks      city
# 0   vikas     23  amritsar
# 1  sanchi     64  varanasi
# 2   tushi     24    ranchi
# 3     adi     22  tirupati

# %% [markdown]
# **DataFrame to CSV**

# %%
df.to_csv('data.csv')

# %% [markdown]
# **Deleting Index in csv file**

# %%
df.to_csv('data2.csv', index = False)

# %% [markdown]
# **Showing first and last two rows**

# %%
df.head(2)
# Out:
#      name  marks      city
# 0   vikas     23  amritsar
# 1  sanchi     64  varanasi

# %%
df.tail(2)
# Out:
#     name  marks      city
# 2  tushi     24    ranchi
# 3    adi     22  tirupati

# %% [markdown]
# **Calculate Mean, Avg & other**

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   33.250000
# std    20.516254
# min    22.000000
# 25%    22.750000
# 50%    23.500000
# 75%    34.000000
# max    64.000000

# %% [markdown]
# **Reading CSV file**
#
# Name = pd.read_csv('file name or path')

# %%
vikas = pd.read_csv('/content/vikas.csv')

# %%
vikas
# Out:
#         no  stations      city
# 0  1245432        23  amritsar
# 1  2387654        64  varanasi
# 2  9876987        24    ranchi
# 3  6587654        22  tirupati

# %% [markdown]
# **Changing values in datasets**

# %%
vikas['no'][0] = 20202020
# Out:
# <ipython-input-73-bc8f7c081155>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vikas['no'][0] = 20202020

# %%
vikas
# Out:
#          no  stations      city
# 0  20202020        23  amritsar
# 1   2387654        64  varanasi
# 2   9876987        24    ranchi
# 3   6587654        22  tirupati

# %% [markdown]
# **Changing the whole column**

# %%
vikas.index = ['first', 'second', 'third', 'fourth']

# %%
vikas
# Out:
#               no  stations      city
# first   20202020        23  amritsar
# second   2387654        64  varanasi
# third    9876987        24    ranchi
# fourth   6587654        22  tirupati

# %% [markdown]
# **Series in pandas**

# %%
ser = pd.Series(np.random.rand(30))

# %%
ser
# Out:
# 0     0.512938
# 1     0.480281
# 2     0.678866
# 3     0.138686
# 4     0.549760
# 5     0.881355
# 6     0.770283
# 7     0.384070
# 8     0.809448
# 9     0.653572
# 10    0.127836
# 11    0.270784
# 12    0.932130
# 13    0.228413
# 14    0.580254
# 15    0.270864
# 16    0.078463
# 17    0.039886
# 18    0.226985
# 19    0.665095
# 20    0.004776
# 21    0.268147
# 22    0.959304
# 23    0.183319
# 24    0.190792
# 25    0.673745
# 26    0.899354
# 27    0.057911
# 28    0.709154
# 29    0.338156
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **DataFrame in Pandas**

# %%
newdf = pd.DataFrame(np.random.rand(50, 5), index=np.arange(50))

# %%
newdf
# Out:
#            0         1         2         3         4
# 0   0
# 11  0.957527  0.224739  0.066018  0.519596  0.845675
# 12   0.23167  0.452016  0.128752  0.888511  0.188786
# 13  0.423121  0.450347  0.474601  0.993385  0.511630
# 14   0.66038  0.972839  0.760968  0.310470  0.413532
# 15  0.236465  0.951746  0.545661  0.605512  0.615079
# 16  0.683111  0.767687  0.414623  0.406014  0.140977
# ...

# %%
#for Avoiding such situation use .copy() 
# it creats copy
newdf2 = newdf.copy()

# %%
newdf.loc[0,0] = 123

# %%
newdf.head(2)
# Out:
#           0         1         2         3         4
# 0       123  0.349280  0.322755  0.233318  0.122134
# 1  0.499786  0.692622  0.542448  0.236612  0.344200

# %%
newdf.columns = list("ABCDE")

# %%
newdf.head(4)
# Out:
#           A         B         C         D         E
# 0       123  0.349280  0.322755  0.233318  0.122134
# 1  0.499786  0.692622  0.542448  0.236612  0.344200
# 2  0.261675  0.204716  0.988781  0.718397  0.891178
# 3    0.9294  0.302532  0.688212  0.481383  0.985777

# %%
newdf.loc[0,'A'] = 321

# %%
newdf.head(4)
# Out:
#           A         B         C         D         E
# 0       321  0.349280  0.322755  0.233318  0.122134
# 1  0.499786  0.692622  0.542448  0.236612  0.344200
# 2  0.261675  0.204716  0.988781  0.718397  0.891178
# 3    0.9294  0.302532  0.688212  0.481383  0.985777

# %%
newdf = newdf.drop("A", axis = 1)

# %%
newdf
# Out:
#            B         C         D         E
# 0   0.349280  0.322755  0.233318  0.122134
# 1   0.692622  0.542448  0.236612  0.344200
# 2   0.204716  0.988781  0.718397  0.891178
# 3   0.302532  0.688212  0.481383  0.985777
# 4   0.102859  0.856712  0.326055  0.598970
# 5   0.113705  0.703182  0.110449  0.184796
# 6   0.868758  0.237733  0.091194  0.226218
# 7   0.185728  0.347142  0.571539  0.887301
# 8   0.760605  0.923525  0.511861  0.189607
# 9   0.274805  0.914607  0.183615  0.591766
# 10  0.022698  0.301787  0.183912  0.436639
# 11  0.224739  0.066018  0.519596  0.845675
# 12  0.452016  0.128752  0.888511  0.188786
# 13  0.450347  0.474601  0.993385  0.511630
# 14  0.972839  0.760968  0.310470  0.413532
# 15  0.951746  0.545661  0.605512  0.615079
# 16  0.767687  0.414623  0.406014  0.140977
# 17  0.639718  0.078260  0.327897  0.022377
# 18  0.981985  0.660445  0.268601  0.144296
# 19  0.052608  0.575042  0.119640  0.163095
# 20  0.073111  0.821762  0.230403  0.334674
# ...

# %%
newdf.loc[[1,2], ['C', 'D']]
# Out:
#           C         D
# 1  0.542448  0.236612
# 2  0.988781  0.718397

# %%
newdf.loc[[1,2], :]
# Out:
#           B         C         D         E
# 1  0.692622  0.542448  0.236612  0.344200
# 2  0.204716  0.988781  0.718397  0.891178

# %%
newdf.loc[:, ['C', 'D']]

# %%
newdf.loc[(newdf['B'] > 0.3) & (newdf['C'] > 0.4)]
# Out:
#            B         C         D         E
# 1   0.692622  0.542448  0.236612  0.344200
# 3   0.302532  0.688212  0.481383  0.985777
# 8   0.760605  0.923525  0.511861  0.189607
# 13  0.450347  0.474601  0.993385  0.511630
# 14  0.972839  0.760968  0.310470  0.413532
# 15  0.951746  0.545661  0.605512  0.615079
# 16  0.767687  0.414623  0.406014  0.140977
# 18  0.981985  0.660445  0.268601  0.144296
# 21  0.812612  0.586651  0.125986  0.298773
# 22  0.457265  0.997457  0.826784  0.991072
# 23  0.436283  0.827311  0.846330  0.078660
# 31  0.496068  0.800079  0.135095  0.821082
# 40  0.593927  0.998277  0.749831  0.098594
# 42  0.335621  0.705292  0.181497  0.160169
# 43  0.949360  0.507790  0.549958  0.397010
# 49  0.345794  0.601225  0.768500  0.254248

# %%
newdf.iloc[2, 3]
# Out:
# 0.8911782311823012

# %%
newdf.head(5)
# Out:
#           B         C         D         E
# 0  0.349280  0.322755  0.233318  0.122134
# 1  0.692622  0.542448  0.236612  0.344200
# 2  0.204716  0.988781  0.718397  0.891178
# 3  0.302532  0.688212  0.481383  0.985777
# 4  0.102859  0.856712  0.326055  0.598970

# %%
newdf.iloc[[2, 4], [1,3]]
# Out:
#           C         E
# 2  0.988781  0.891178
# 4  0.856712  0.598970

# %%
newdf.head(5)
# Out:
#           B         C         D         E
# 0  0.349280  0.322755  0.233318  0.122134
# 1  0.692622  0.542448  0.236612  0.344200
# 2  0.204716  0.988781  0.718397  0.891178
# 3  0.302532  0.688212  0.481383  0.985777
# 4  0.102859  0.856712  0.326055  0.598970

# %%
newdf.drop(['C'], axis = 1) # for droping column
# Out:
#            B         D         E
# 0   0.349280  0.233318  0.122134
# 1   0.692622  0.236612  0.344200
# 2   0.204716  0.718397  0.891178
# 3   0.302532  0.481383  0.985777
# 4   0.102859  0.326055  0.598970
# 5   0.113705  0.110449  0.184796
# 6   0.868758  0.091194  0.226218
# 7   0.185728  0.571539  0.887301
# 8   0.760605  0.511861  0.189607
# 9   0.274805  0.183615  0.591766
# 10  0.022698  0.183912  0.436639
# 11  0.224739  0.519596  0.845675
# 12  0.452016  0.888511  0.188786
# 13  0.450347  0.993385  0.511630
# 14  0.972839  0.310470  0.413532
# 15  0.951746  0.605512  0.615079
# 16  0.767687  0.406014  0.140977
# 17  0.639718  0.327897  0.022377
# 18  0.981985  0.268601  0.144296
# 19  0.052608  0.119640  0.163095
# 20  0.073111  0.230403  0.334674
# 21  0.812612  0.125986  0.298773
# 22  0.457265  0.826784  0.991072
# 23  0.436283  0.846330  0.078660
# 24  0.153985  0.209290  0.599839
# 25  0.667100  0.400931  0.600762
# 26  0.789517  0.849358  0.347762
# ...

# %%
newdf.drop([2]) # for droping row 
# inplace= true will save in newdf
# Out:
#            B         C         D         E
# 0   0.349280  0.322755  0.233318  0.122134
# 1   0.692622  0.542448  0.236612  0.344200
# 3   0.302532  0.688212  0.481383  0.985777
# 4   0.102859  0.856712  0.326055  0.598970
# 5   0.113705  0.703182  0.110449  0.184796
# 6   0.868758  0.237733  0.091194  0.226218
# 7   0.185728  0.347142  0.571539  0.887301
# 8   0.760605  0.923525  0.511861  0.189607
# 9   0.274805  0.914607  0.183615  0.591766
# 10  0.022698  0.301787  0.183912  0.436639
# 11  0.224739  0.066018  0.519596  0.845675
# 12  0.452016  0.128752  0.888511  0.188786
# 13  0.450347  0.474601  0.993385  0.511630
# 14  0.972839  0.760968  0.310470  0.413532
# 15  0.951746  0.545661  0.605512  0.615079
# 16  0.767687  0.414623  0.406014  0.140977
# 17  0.639718  0.078260  0.327897  0.022377
# 18  0.981985  0.660445  0.268601  0.144296
# 19  0.052608  0.575042  0.119640  0.163095
# 20  0.073111  0.821762  0.230403  0.334674
# 21  0.812612  0.586651  0.125986  0.298773
# ...

# %%
newdf.reset_index(drop =True, inplace=True)

# %%
newdf.head(4)
# Out:
#           B         C         D         E
# 0  0.349280  0.322755  0.233318  0.122134
# 1  0.692622  0.542448  0.236612  0.344200
# 2  0.204716  0.988781  0.718397  0.891178
# 3  0.302532  0.688212  0.481383  0.985777

# %%
newdf['B'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: B, dtype: bool

# %%
newdf['B'] =None
#newdf.loc[:, ['B']] = None

# %%
newdf
# Out:
#        B         C         D         E
# 0   None  0.322755  0.233318  0.122134
# 1   None  0.542448  0.236612  0.344200
# 2   None  0.988781  0.718397  0.891178
# 3   None  0.688212  0.481383  0.985777
# 4   None  0.856712  0.326055  0.598970
# 5   None  0.703182  0.110449  0.184796
# 6   None  0.237733  0.091194  0.226218
# 7   None  0.347142  0.571539  0.887301
# 8   None  0.923525  0.511861  0.189607
# 9   None  0.914607  0.183615  0.591766
# 10  None  0.301787  0.183912  0.436639
# 11  None  0.066018  0.519596  0.845675
# 12  None  0.128752  0.888511  0.188786
# 13  None  0.474601  0.993385  0.511630
# 14  None  0.760968  0.310470  0.413532
# 15  None  0.545661  0.605512  0.615079
# 16  None  0.414623  0.406014  0.140977
# 17  None  0.078260  0.327897  0.022377
# 18  None  0.660445  0.268601  0.144296
# 19  None  0.575042  0.119640  0.163095
# 20  None  0.821762  0.230403  0.334674
# 21  None  0.586651  0.125986  0.298773
# 22  None  0.997457  0.826784  0.991072
# ...

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwomen'],
                   "toy": [np.nan, 'Batmobil', 'Bullwhip'],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"), pd.NaT]})

# %%
df
# Out:
#        name       toy       born
# 0    Alfred       NaN        NaT
# 1    Batman  Batmobil 1940-04-25
# 2  Catwomen  Bullwhip        NaT

# %%
df.dropna(how = 'all')
# Out:
#        name       toy       born
# 0    Alfred       NaN        NaT
# 1    Batman  Batmobil 1940-04-25
# 2  Catwomen  Bullwhip        NaT

# %%
df2 = pd.DataFrame({"name": ['Alfred', 'Batman', 'Alfred'],
                   "toy": [np.nan, 'Batmobil', 'Bullwhip'],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"), pd.NaT]})

# %%
df2.drop_duplicates(subset=['name'], keep = 'last') # keep last record
# Out:
#      name       toy       born
# 1  Batman  Batmobil 1940-04-25
# 2  Alfred  Bullwhip        NaT

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   toy     2 non-null      object
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 200.0+ bytes

# %%
df2['toy'].value_counts(dropna=True)
# Out:
# Batmobil    1
# Bullwhip    1
# Name: toy, dtype: int64

# %%
df2.isnull()
# Out:
#     name    toy   born
# 0  False   True   True
# 1  False  False  False
# 2  False  False   True

# %%
#create dataframe which contains only integers with 3 rows and 2 columns
#run following
df.describe()
df.mean()
df.corr()
df.count()
df.max()
df.min()
df.median()
df.std()

# %%
pip install xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#data = pd.read_excel('/content/vikas.csv')
